# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroInvicta/Practicas/blob/main/YOLO_Plane_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inicio cargando paquete por ultralytics
# ## Esta paqueteria contiene un modelo sin entrenamiento pero con pesos y medidas predefinidas

# %%
pip install ultralytics opencv-python

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tFYIK797b1m72tnaGceK")
project = rf.workspace("drone-qyveq").project("aircraft-bnbcm")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 93.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 144.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to aircraft-1 in yolov8:: 100%|██████████| 1855/1855 [00:00<00:00, 2256.14it/s]
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/aircraft-1/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import display
# Open the image
img = Image.open('/content/runs/detect/train/results.png')

# Resize to specific dimensions (e.g., 300x200)
resized_img = img.resize((800, 500))

# Display the resized image
display(resized_img)
# Out:
# <PIL.Image.Image image mode=RGBA size=800x500>

# %%
from google.colab import files
files.download("runs/detect/train/weights/best.pt")
